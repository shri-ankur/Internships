# %%
import numpy as np
import pandas as pd
import xlrd

#Read in all the datasets
#Make changes as necessary to point to raw data files
accurate_df = pd.read_excel("..\Datascience Intern\Accurate_Lakshya_22_01_2018 done.xlsx")
all_India_5000_df = pd.read_excel("..\Datascience Intern\ALL-INDIA-NETWORK-5000 data hms.xls")
all_India_general_df = pd.read_excel("..\Datascience Intern\ALL-INDIA-NETWORK-HOSPITALS-GENERAL (2).xls")
data_research_df = pd.read_excel("..\Datascience Intern\Data_research_22_02_2018 (1).xlsx")
fups_hms_df = pd.read_excel("..\Datascience Intern\\fups_hms_14-02-18.xlsx")
hms_mahima_df = pd.read_excel("..\Datascience Intern\hms_100bedsdata_27_02_18 mahima.xlsx")
hms_alldata_df = pd.read_excel("..\Datascience Intern\HMS_alldata_lakshya_22-02-18.xlsx")
hms_lakshya_df = pd.read_excel("..\Datascience Intern\hms_data100beds_27-02-18 lakshya.xlsx", sheetname=1)
hms_dataentry_df = pd.read_excel("..\Datascience Intern\hms_dataentry_22-02-18.xlsx")
hms_leadfile_df = pd.read_excel("..\Datascience Intern\HMS_LeadFile_14-02-2018.xlsx")
hms_uttarakhand_df = pd.read_excel("..\Datascience Intern\HMS_Uttrakhand_21_02_2018.xlsx")
hospital_data_df = pd.read_excel("..\Datascience Intern\Hospital Data.xlsx")
hospital_laksh_8_02_df = pd.read_excel("..\Datascience Intern\Hospital_laksh_8_02_18.xlsx")
hospital_laksh_23_01_df = pd.read_excel("..\Datascience Intern\Hospital_laksh_23_01_18 and 9-02-18.xlsx")
indiahospital_laksh1_df = pd.read_excel("..\Datascience Intern\indiahospital_laksh_9-02-18.xls", sheetname=1, skiprows=3)
indiahospital_laksh2_df = pd.read_excel("..\Datascience Intern\indiahospital_laksh_9-02-18.xls", sheetname=2, skiprows=3)
indiahospital_laksh3_df = pd.read_excel("..Datascience Intern\indiahospital_laksh_9-02-18.xls", sheetname=3, skiprows=3)
indiahospital_laksh4_df = pd.read_excel("..\Datascience Intern\indiahospital_laksh_9-02-18.xls", sheetname=4, skiprows=3)
jharkhand_df = pd.read_excel("..\Datascience Intern\jharkhand and Chattisgarh.xlsx")
mahima_hms_df = pd.read_excel("..\Datascience Intern\Mahima_HMS_22-02-18.xlsx")

# %% [markdown]
# Check first few row of all datasets to see if they have been correctly imported.

# %%
accurate_df.head()
# Out:
#    Sr_No                                           Location  \
# 0    201  Vimal Hospital,Near Govt Boys High School,Barnala
# 1    202                                   K C Road Barnala
# 2    203  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road Ba...
# 3    204                             Kacha College, Barnala
# 4    205                    Sangrur Road, Dhanuala, Barnala
#
#                           Hospital_Name Hospital_Category  Hospital_Care_Type  \
# 0               Dr Parmod Jain Hospital                 0                   0
# 1            Dr Pradeep Sharma Hospital                 0                   0
# 2             Dr Rakesh Surgical Center                 0                   0
# 3  Dr. Naresh Hospital and Heart Centre                 C                   0
# 4        G M S Multispeciality Hospital                 0                   0
#
#    Discipline_Systems_of_Medicine  \
# 0                               0
# 1                               0
# ...

# %%
all_India_5000_df.head()
# Out:
#    SL NO  NAME OF THE HOSPITAL                         ADDRESS-1  \
# 0      1  KAILASH HOSPITAL LTD        23, KNOWLEDGE GREEN PARK-1
# 1      2     A.B.EYE INSTITUTE  NEAR BAHADURPUR RAILWAY CROSSING
# 2      3          A.C.HOSPITAL                  104,II AGRAHARAM
# 3      4          A.G.HOSPITAL                    34, KPN COLONY
# 4      5        A.G.M.HOSPITAL        923, POONAMALLEE HIGH ROAD
#
#                ADDRESS-2           CITY       DISTRICT         STATE   \
# 0     INSTITUTIONAL AREA  GREATER NOIDA  GREATER NOIDA  UTTAR PRADESH
# 1          RAJENDRANAGAR          PATNA          PATNA          BIHAR
# 2                  SALEM          SALEM          SALEM     TAMIL NADU
# 3             3RD STREET        TIRUPUR        TIRUPUR     TAMIL NADU
# 4  POONAMALLEE HIGH ROAD        CHENNAI        CHENNAI     TAMIL NADU
#
#    PINCODE STD CODE            PHONE NO.
# 0   201305     0120              2321111
# 1   800016     0612              2670292
# ...

# %%
all_India_general_df.head()
# Out:
#    SL NO  NAME OF THE HOSPITAL                         ADDRESS-1  \
# 0      1  KAILASH HOSPITAL LTD        23, KNOWLEDGE GREEN PARK-1
# 1      2     A.B.EYE INSTITUTE  NEAR BAHADURPUR RAILWAY CROSSING
# 2      3          A.C.HOSPITAL                  104,II AGRAHARAM
# 3      4          A.G.HOSPITAL                    34, KPN COLONY
# 4      5        A.G.M.HOSPITAL        923, POONAMALLEE HIGH ROAD
#
#                ADDRESS-2           CITY       DISTRICT         STATE   \
# 0     INSTITUTIONAL AREA  GREATER NOIDA  GREATER NOIDA  UTTAR PRADESH
# 1          RAJENDRANAGAR          PATNA          PATNA          BIHAR
# 2                  SALEM          SALEM          SALEM     TAMIL NADU
# 3             3RD STREET        TIRUPUR        TIRUPUR     TAMIL NADU
# 4  POONAMALLEE HIGH ROAD        CHENNAI        CHENNAI     TAMIL NADU
#
#    PINCODE STD CODE            PHONE NO.
# 0   201305     0120              2321111
# 1   800016     0612              2670292
# ...

# %%
data_research_df.head()
# Out:
#        Index             Company Name  \
# Swati      1            3M India Ltd
# Swati      2           ABB India Ltd
# Swati      3                BEML Ltd
# Swati      4                      NaN
# Swati      5  Bharat Electronics Ltd
#
#                                                 Industry  \
# Swati  Electrical , Electronics, Food , FMCG , Agricu...
# Swati                           Electrical , Electronics
# Swati                           Capital Goods , Machines
# Swati                                                NaN
# Swati                           Electrical , Electronics
#
#                                             Sub Industry     Company Type  \
# Swati  FMCG, Equipments , Machines , Surgical Product...  India's Top 500
# Swati                           Electrical , Electronics  India's Top 500
# Swati                                                NaN  India's Top 500
# Swati                                                NaN              NaN
# ...

# %%
fups_hms_df.head()
# Out:
#   Allocated to  SL NO                               NAME OF THE HOSPITAL  \
# 0      Lakshya    211                             APEX HOSPITALS PVT LTD
# 1      Lakshya    213  APEX HOSPITAL(STEEL CITY CRITICAL CARE UNIT PV...
# 2      Lakshya    219  APOLLO BSR HOSPITALS(A UNIT OF BSR SUPERSPECIA...
# 3      Lakshya    208                                   ANUPAMA HOSPITAL
# 4      Lakshya      7                       AJHOSPITAL & RESEARCH CENTRE
#
#    Number Of Bed         Contact Name Designation    Contact Number  \
# 0            NaN         Mr.Rameshwar         NaN               NaN
# 1          100.0          Mr.Nagendra     Head IT       09866734910
# 2          175.0           Mr.Praveen     Head IT               NaN
# 3          100.0  Mr.Lakshmipati Raju         NaN               NaN
# 4          350.0    Sharada J. Shetty    Director  +91 824 222 5533
#
#                         Email                               ADDRESS-1  \
# ...

# %%
hms_mahima_df.head()
# Out:
#    Sr.No.         Region                                      Hospital Name  \
# 0       1  RO Aurangabad                    Govt.Medical College & Hospital
# 1       2  RO Aurangabad                    MGM Medical College\n& Hospital
# 2       3  RO Aurangabad  Marathwada Medical & Research Institute\n( Kam...
# 3       4  RO Aurangabad                       Seth Nandalal Dhoot Hospital
# 4       5  RO Aurangabad  Dr. Hedgewar Rugnalay\n& Dattaji Bhale Blood Bank
#
#                                              Address  Beds  Contact numbers
# 0                   Ghati, Panchakki Road Aurangabad  1020    0240 240 2412
# 1                            N-06, Cidco, Aurangabad   500  : 0240 660 1100
# 2  Gat No-43, Beed By Pass Road, Satara Parisar, ...   135      98220-50629
# 3                Plot No.A-1, A-2, MIDC\nChikalthana   200    0240 247 8500
# 4        Jawahar Colony Garkheda Parisar, Aurangabad   150    0240 233 1195

# %%
hms_alldata_df.head()
# Out:
#    S.no.                              Hospital  \
# 0    503            CARE HOSPITAL-SECUNDERABAD
# 1    504  CAREER INSTITUTE OF MEDICAL SCIENCES
# 2    505                      CAUVERY HOSPITAL
# 3    506            CAVVERY ORTHOPAEDIC CENTRE
# 4    507                CAUVERY TRUST HOSPITAL
#
#                                             Address         Address.1  \
# 0  NEAR CLOCK TOWER, ADJACENT LANE TO WESLEY CHURCH    MARKET STREET
# 1                  CAREER COLLEGE CAMPUS GOVINDPURA       BHEL BHOPAL
# 2                                   TERISIAN CRICLE  SIDDARTHA LAYOUT
# 3                       # 408, 20TH MAIN, IST BLOCK      RAJAJI NAGAR
# 4                        NO-36, PONNANKINARU STREET       VILLIVAKKAM
#
#         City           State Unnamed: 6  State Code              Number Beds  \
# 0  HYDERABAD       TELANGANA     500003          40  66267777/ 27717736  NaN
# 1     BHOPAL  MADHYA PRADESH     462023         755    2488090/2488680   NaN
# ...

# %%
hms_lakshya_df.head()
# Out:
#             Sr.No.          Region  \
# 0  Date:26-02-2018             NaN
# 1                1         SROM-II
# 2                3     Mumbai -III
# 3                4         SROM-IV
# 4                8  RO Pune region
#
#                                        Hospital Name  \
# 0                                                NaN
# 1  M/s Guru nanak quit cenernary , Gurunanak hosp...
# 2                            Godrej Memorial Hospita
# 3                                   Karuna Hospital,
# 4                                  Bel Air Hospital,
#
#                                          Address Beds Contact Number  \
# 0                                            NaN  NaN            NaN
# 1   s-341 Gandhi nagar Bandra\n(E) Mumbai-400051  120  022 4222 7777
# 2               Phirozshah Vikhroli E Mumbai\n79  111  022 6641 7100
# 3                Borivali (W), Mumbai – 400\n103  156   098737 53999
# 4  Pachgani, Tal - Mahabaleshwar, Dist - Satara.  200  02168 240 309
#
# ...

# %%
hms_dataentry_df.head()
# Out:
#        Sr.No.   Region                                 Hospital Name  \
# 202.0    38.0   SROM-I                         Balaji Heart Hospital
# 203.0    39.0  SROM-II  Dr. R.N Cooper, Municipal General Hospital ,
# 204.0    40.0  SROM-II          Bandra Holly Family Hospital Society
# 205.0    41.0  SROM-II     M/s. Lilavati Hospital & Research Centre,
# 206.0    42.0  SROM-II                    M/s. Asian Heart Hospital,
#
#                                                  Address   Beds Contact Number
# 202.0    Victoria Road, Cross Lane III\nByculla (E) M-27  100.0  022 2374 0000
# 203.0                     Johu, VilePare-(W),Mumbai- 56.  390.0  022 2620 7254
# 204.0               St. Andrew Rd, Bandra-(W), Mumbai-60  232.0  022 6267 0555
# 205.0                    A- 791,Bandra.(W).    Mumbai 50  320.0  022 2675 1000
# 206.0  G/N Block Bandra Kurla Complex, Bandhra- (E),M...  230.0  022 6739 6666

# %%
hms_leadfile_df.head()
# Out:
#    S.No.      Date                                Hospital Name  \
# 0    NaN  8/2/2018                                          NaN
# 1    1.0       NaN                 Shree Balaji Chadha Hospital
# 2    2.0       NaN                 Dr Raman Goyals Eye Hospital
# 3    NaN  9/2/2018                                          NaN
# 4    3.0       NaN  MISSION OF MERCY HOSPITAL & RESEARCH CENTRE
#
#    Number Of Bed    Contact Name Designation Contact Number Email ID  \
# 0            NaN             NaN         NaN            NaN      NaN
# 1          120.0    Mr.DR Sharma         NaN            NaN      NaN
# 2            NaN  Dr.Raman Goyal         NaN            NaN      NaN
# 3            NaN             NaN         NaN            NaN      NaN
# 4          173.0             NaN         NaN            NaN      NaN
#
#                                       ADDRESS-1 ADDRESS-2         CITY  \
# 0                                           NaN       NaN          NaN
# ...

# %%
hms_uttarakhand_df.head()
# Out:
#    S.No.                       Hospital Name City/ Town  \
# 0      1              MN Srivastava Hospital     Almora
# 1      2             Combined Medical Centre   Dehradun
# 2      3         Hari Ram Kohli Nursing Home   Dehradun
# 3      4  Krishna Hospital & Research Centre   Haldwani
# 4      5                        Sai Hospital   Haldwani
#
#                                              Address  \
# 0  Raniketh; Kalika; Almora; Dist:Almora; Uttaran...
# 1  54, Haridwar Road; Dehradun; Dist:Dehradun; Ut...
# 2  2, Haridwar Road; Dehradun; Dist:Dehradun; Utt...
# 3  3-136; Guru Nanak Pura; Haldwani - 263141; Dis...
# 4  Near Mukani Chauraha; Haldwani - 263139; Dist:...
#
#                               Contact Person  \
# 0                 Dr. Renu Prakash Srivastav
# 1  Mr. Rajiv Ranjan - Hospital Administrator
# 2                           Dr. Harish Kohli
# 3         Mrs. Anju Mongia - General Manager
# 4         Dr. Mohan Sati - Managing Director
#
# ...

# %%
hospital_data_df.head()
# Out:
#    S.No.  Region                         Name  \
# 0      1  Nashik     M/s. St. Luke's Hospital
# 1      2  Nashik  M/s. Pravara Rural Hospital
# 2      3  Nashik       M/s. F.J.F.M. Hospital
# 3      4  Nashik        M/s. Saibaba Hospital
# 4      5  Nashik   M/s. Shri Sainath Hospital
#
#                                             Address  Beds  \
# 0               Ward no. 1,Shrirampur Dsit. A'nagar   200
# 1               At. Loni BK,Tal.Rahata Dist.A'nagar   750
# 2          Vadala Mission Tal. Newasa Dist. A'nagar   150
# 3  Opp. Bus Stand,Shirdi, Tal. Rahata Dist. A,nagar   200
# 4  Opp. Bus Stand,Shirdi, Tal. Rahata Dist. A,nagar   300
#
#               Validity                  Contact No Contact Person  \
# 0            8/31/2011               02422 223 663        Ms.Rosi
# 1  2011-11-30 00:00:00             +91-2422–271277            NaN
# 2  2010-07-31 00:00:00  9192427247335+919226392894            NaN
# ...

# %%
hospital_laksh_8_02_df.head()
# Out:
#    Sr. No.                       Provider Name  Tel Area  \
# 0        1                       SOOD HOSPITAL      1675
# 1        2                      BAJWA HOSPITAL       183
# 2        3          CHOUDARY ENT MATERNITY AND       183
# 3        4  DR. H. R. NAYYAR MEMORIAL HOSPITAL       183
# 4        5     DR. OM PARKASH SATYAM NETRALAYA       183
#
#                  Tel No.  Category  \
# 0                 245404  Hospital
# 1                2423800  Hospital
# 2        5014995/2521722  Hospital
# 3  211686 /562051 /62050  Hospital
# 4      2221128 / 2221132  Hospital
#
#                                           Address   State       City  \
# 0      Near Gandhi School,Dahleej Road,,Ahmedgarh  Punjab  Ahmedgarh
# 1       322/23, Akash Avenue,,Fateh Garh, Churian  Punjab   Amritsar
# 2  Near Old State Bank Of India ,,,Katra-Khazand,  Punjab   Amritsar
# 3               3, Dasondha Singh Road,,,Amritsar  Punjab   Amritsar
# ...

# %%
hospital_laksh_23_01_df.head()
# Out:
#   Allocated to  SL NO  NAME OF THE HOSPITAL Number Of Bed  \
# 0      Lakshya      1  KAILASH HOSPITAL LTD           150
# 1      Lakshya      2       ABEYE INSTITUTE           NaN
# 2      Lakshya      3            ACHOSPITAL            30
# 3      Lakshya      4            AGHOSPITAL            20
# 4      Lakshya      5           AGMHOSPITAL           72
#
#                     Contact Name             Designation Contact Number Email  \
# 0                    Mr. Hemanth  Medical Superintendent    01202466666   NaN
# 1                 Md Arshad Azad           Chief Manager  98011 - 89547   NaN
# 2  Dr. Dr.C.Dev Krishna Bharathi         General Surgeon     4426743052   NaN
# 3                            NaN                     NaN            NaN   NaN
# 4                            NaN                     NaN            NaN   NaN
#
#                           ADDRESS-1              ADDRESS-2           CITY  \
# ...

# %%
indiahospital_laksh1_df.head()
# Out:
#    SL. NO.        CITY                    Catogory  \
# 0        1  Amalapuram  General Hospital
# 1        1   Anantapur  General Hospital
# 2        2   Anantapur  General Hospital
# 3        1    Cuddapah  General Hospital
# 4        1      Guntur  General Hospital
#
#                                    NAME OF HOSPITAL  \
# 0                                    CARE HOSPITALS
# 1                                  APOLLO HOSPITALS
# 2                           JEEVANA JYOTHI HOSPITAL
# 3                           SRI SAI KRUPA HOSPITALS
# 4  AMARAVATHI INSTITUTE OF MEDICAL SCIENCES PVT LTD
#
#                                              ADDRESS          STATE  \
# 0                              Konaseema, Amalapuram  ANDRA PRADESH
# 1                             Court Road, Ananthapur  ANDRA PRADESH
# 2                   #15/381, KAMALA NAGAR, ANANTAPUR  ANDRA PRADESH
# 3  5/262,Vinayakanagar,Cuddapah,Kurnool rd nh-18,...  ANDRA PRADESH
# ...

# %%
indiahospital_laksh2_df.head()
# Out:
#    SL. NO.          CITY  CATOGORY                 NAME OF HOSPITAL  \
# 0        1        AMBALA       NaN    ANEJA HOSPITAL & NURSING HOME
# 1        2        AMBALA       NaN  LOOMBA MATERNITY & ENT HOSPITAL
# 2        3        AMBALA       NaN              M.K. DATTA HOSPITAL
# 3        1  Bahadur Garh       NaN  BRAHM SHAKTI SANJIVANI HOSPITAL
# 4        2  BAHADUR GARH       NaN            JEEVAN JYOTI HOSPITAL
#
#                                              ADDRESS    STATE  \
# 0    # 48, BABYAL ROAD, AMBALA CANTT., AMBALA-133001  HARYANA
# 1            Alexandria Rd,Supply chowk,Ambala Cannt  HARYANA
# 2                             AMBALA CANTT., HARYANA  HARYANA
# 3     Opp Telephone Exchange, Dist. Jhajjar, Haryana  HARYANA
# 4  DELHI ROHTAK ROAD, M.I.E.,B. GARH, BAHADURGARH...  HARYANA
#
#                              TEL/FAX Contact Name No OF BEDS Contact Updated  \
# 0         (0171) 2661901/2661902  F:          NaN        NaN           NORTH
# ...

# %%
indiahospital_laksh3_df.head()
# Out:
#    SL. NO.       CITY  CATEGORY  \
# 0        1  Dibrugarh       NaN
# 1        1  Bhagalpur       NaN
# 2        1    Kathiar       NaN
# 3        1      PATNA       NaN
# 4        2      PATNA       NaN
#
#                                   NAME OF HOSPITAL  \
# 0  SHRISHTI HOSPITAL AND RESEARCH CENTRE PVT. LTD.
# 1     LIFE LINE DIAGNOSTIC CENTRE CUM NURSING HOME
# 2                              MANISH NURSING HOME
# 3                            APPOLO BURNS HOSPITAL
# 4                      DR. RUBAN MEMORIAL HOSPITAL
#
#                                 ADDRESS  STATE                     TEL/FAX  \
# 0               Paltan Bazar, Dibrugarh  ASSAM                  3732300024
# 1        Khalifabag, Bhagalpur - 812002  BIHAR  0641-408022, 033 4026 7400
# 2    R K Mission Road, Kathiar - 854105  BIHAR          33081, 98352-20860
# 3        Dhanki More,Near Mazar,Kumhrar  BIHAR             +91 96500 69488
# 4  Minar Plaza,South eat gahndi maidan,  BIHAR               0612 227 0059
#
# ...

# %%
indiahospital_laksh4_df.head()
# Out:
#    SL. NO.    CITY Catogory                      NAME OF HOSPITAL  \
# 0        1   DAMAN      NaN         ATMARAM JOG MEMORIAL HOSPITAL
# 1        2   DAMAN      NaN               HANSA CLINIC & HOSPITAL
# 2        1     Goa      NaN  GRACE INTENSIVE CARDIAC CARE CENTER
# 3        2     Goa      NaN                    VRUNDAVAN HOSPITAL
# 4        1  PANJIM      NaN                 DR. BHANDARE HOSPITAL
#
#                                              ADDRESS  STATE  \
# 0            DUNTHA ROAD, DAMANDAMAN UNION TERRITORY  DAMAN
# 1          MAIN ROAD, DABHEL,NANI DAMANDAMAN- 396115  DAMAN
# 2  Opp : B P S Club, Behind Astro Housing Society...    GOA
# 3  Teun Industrial Estate Pedum karasarada, Goa-4...    GOA
# 4                       FONTAINHAS PANAJI NORTH, GOA    GOA
#
#                              TEL/FAX Updated Number  No OF BEDS  Status   \
# 0                 (0260) 2262190  F:            NaN         NaN      NaN
# ...

# %%
jharkhand_df.head()
# Out:
#    S.No.                           Hospital Name City/ Town  \
# 0      1  Siddhesh Swastha Seva Shalya Pvt. Ltd.  Adityapur
# 1      2  Dhanwantari Orthopedic & Trauma Centre     Bokaro
# 2      3                             Mother Care     Bokaro
# 3      4     Muskan Hospital and Research Centre     Bokaro
# 4      5             Shanti Health Care Hospital     Bokaro
#
#                                              Address  \
# 0  Adityapur Main Road; Adityapur - 831013; Dist:...
# 1  132, Co-operative Colony; Bokaro Steel City; B...
# 2  GE-1, City Centre; Sector-4, Bokaro Steel City...
# 3  Ramnagar Colony, Main Road; Chas; Bokaro - 827013
# 4  Co-operative Colony; Bokaro Steel City; Bokaro...
#
#                  Contact Person  \
# 0          Mrs. Anjali Jha - MD
# 1                 Dr. A K Singh
# 2  Dr. Anju Parira - Consultant
# 3     Dr Manoj Kumar Srivastava
# 4                 Dr. N K Sinha
#
#                                       Contact Number
# ...

# %%
mahima_hms_df.head()
# Out:
#    S.no.                                           Hospital  \
# 0    751                              DR.PATIL ENT HOSPITAL
# 1    752                                DR. PATILS HOSPITAL
# 2    753  DR. PATTNAIK NURSING HOME (SATYA SIVA MEDICALS...
# 3    754                    DR. R.N. PATIL'S SURAJ HOSPITAL
# 4    755  DR. RAGHOJI KIDNEY HOSPITAL & RESEARCH CENTRE ...
#
#                                     Address                         Address.1  \
# 0                  KAMALA CROSS ROAD,B WING       OFF NO37/38,OPP-PCMC OFFICE
# 1                   NEAR HOTEL GARDEN TUNES           NEAR HOTEL GARDEN TUNES
# 2             4,KAKKAD APARTMENT ,PALI ROAD                         BANDRA(W)
# 3                        SUN PALM VIEW BLDG  PLOT NO-171A, SECTOR-15,SANPADA
# 4  146/2, RAILWAY LINES,NR: OLD RTO OFFICE,                           SOLAPUR
#
#       City    State   Unnamed: 6  State Code  Number                Beds  \
# ...

# %% [markdown]
# Changing column names in all hospital dataframes to standard names

# %%
accurate_df.rename(columns={'Sr_No':'S_No', 'Address_Original_First_Line':'Address-1', 'Total_Num_Beds':'Beds', 
                           'Contact Number':'Phone no'}, inplace=True)
accurate_df.columns
# Out:
# Index(['S_No', 'Location', 'Hospital_Name', 'Hospital_Category',
#        'Hospital_Care_Type', 'Discipline_Systems_of_Medicine', 'Address-1',
#        'State', 'District', 'Subdistrict', 'Pincode', 'Website',
#        'Contact Name', 'Designation', 'Phone no', 'Name Head IT',
#        'Contact Head ', 'Beds', 'Status', 'Remarks', 'case'],
#       dtype='object')

# %%
all_India_5000_df.rename(columns={'SL NO':'S_No', 'NAME OF THE HOSPITAL':'Hospital_Name', 'ADDRESS-1':'Address-1',
                                 'ADDRESS-2':'Address-2','CITY':'City','DISTRICT':'District', 'STATE ':'State', 'PINCODE':'Pincode', 'STD CODE':'Std Code',
                                 'PHONE NO.':'Phone no'}, inplace=True)
all_India_5000_df.columns
# Out:
# Index(['S_No', 'Hospital_Name', 'Address-1', 'Address-2', 'City', 'District',
#        'State', 'Pincode', 'Std Code', 'Phone no'],
#       dtype='object')

# %%
all_India_general_df.rename(columns={'SL NO':'S_No', 'NAME OF THE HOSPITAL':'Hospital_Name', 'ADDRESS-1':'Address-1',
                                 'ADDRESS-2':'Address-2','CITY':'City','DISTRICT':'District', 'STATE ':'State', 'PINCODE':'Pincode', 'STD CODE':'Std Code',
                                 'PHONE NO.':'Phone no'}, inplace=True)
all_India_general_df.columns
# Out:
# Index(['S_No', 'Hospital_Name', 'Address-1', 'Address-2', 'City', 'District',
#        'State', 'Pincode', 'Std Code', 'Phone no'],
#       dtype='object')

# %%
fups_hms_df.rename(columns={'SL NO':'S_No', 'NAME OF THE HOSPITAL':'Hospital_Name', 'ADDRESS-1':'Address-1',
                                 'ADDRESS-2':'Address-2','CITY':'City','DISTRICT':'District', 'STATE ':'State', 'PINCODE':'Pincode', 'STD CODE':'Std Code',
                                 'PHONE NO.':'Phone no', 'Number Of Bed':'Beds'}, inplace=True)
fups_hms_df.columns
# Out:
# Index(['Allocated to', 'S_No', 'Hospital_Name', 'Beds', 'Contact Name',
#        'Designation', 'Contact Number', 'Email', 'Address-1', 'Address-2',
#        'City', 'District', 'State', 'Pincode', 'Std Code', 'Phone no',
#        'Status ', 'Remarks', 'Case'],
#       dtype='object')

# %%
hms_mahima_df.rename(columns={'Sr.No.':'S_No', 'Hospital Name':'Hospital_Name','Address':'Address-1','Contact numbers':'Phone no'}, inplace=True)
hms_mahima_df.columns
# Out:
# Index(['S_No', 'Region', 'Hospital_Name', 'Address-1', 'Beds', 'Phone no'], dtype='object')

# %%
hms_alldata_df.rename(columns={'S.no.':'S_No', 'Hospital':'Hospital_Name','Address':'Address-1','Address.1':'Address-2',
                              'Unnamed: 6':'Pincode', 'Unnamed: 12':'Contact Name'}, inplace=True)
hms_alldata_df.columns
# Out:
# Index(['S_No', 'Hospital_Name', 'Address-1', 'Address-2', 'City', 'State',
#        'Pincode', 'State Code', 'Number', 'Beds', 'Status ', 'Remarks',
#        'Contact Name'],
#       dtype='object')

# %%
hms_lakshya_df = hms_lakshya_df.iloc[1:,]

# %%
hms_lakshya_df.rename(columns={'Sr.No.':'S_No', 'Hospital Name':'Hospital_Name','Address':'Address-1','Contact Number':'Phone no',
                               'Contact Person':'Contact Name'}, inplace=True)
hms_lakshya_df.columns
# Out:
# Index(['S_No', 'Region', 'Hospital_Name', 'Address-1', 'Beds', 'Phone no',
#        'Contact Name', 'Direct Number', 'Designation', 'Status ', 'Remarks',
#        'Email ID'],
#       dtype='object')

# %%
hms_dataentry_df.rename(columns={'Sr.No.':'S_No', 'Hospital Name':'Hospital_Name','Address':'Address-1','Contact Number':'Phone no',
                               }, inplace=True)
hms_dataentry_df.columns
# Out:
# Index(['S_No', 'Region', 'Hospital_Name', 'Address-1', 'Beds', 'Phone no'], dtype='object')

# %%
hms_leadfile_df.rename(columns={'S.No.':'S_No','Hospital Name':'Hospital_Name', 'ADDRESS-1':'Address-1',
                                 'ADDRESS-2':'Address-2','CITY':'City','DISTRICT':'District', 'STATE ':'State', 'PINCODE':'Pincode',
                                 'PHONE NO.':'Phone no', 'Number Of Bed':'Beds'}, inplace=True)
hms_leadfile_df.columns
# Out:
# Index(['S_No', 'Date', 'Hospital_Name', 'Beds', 'Contact Name', 'Designation',
#        'Contact Number', 'Email ID', 'Address-1', 'Address-2', 'City',
#        'District', 'State', 'Pincode', 'Phone no', 'Status ', 'Remarks',
#        'Case'],
#       dtype='object')

# %%
hms_uttarakhand_df.rename(columns={'S.No.':'S_No','Hospital Name':'Hospital_Name', 'Address':'Address-1',
                                 'City/ Town':'City','Contact Person':'Contact Name',
                                 'Contact Number':'Phone no', 'Number Of Bed':'Beds'}, inplace=True)
hms_uttarakhand_df.columns
# Out:
# Index(['S_No', 'Hospital_Name', 'City', 'Address-1', 'Contact Name',
#        'Phone no', 'Status', 'Remarks'],
#       dtype='object')

# %%
hospital_data_df.rename(columns={'S.No.':'S_No','Name':'Hospital_Name', 'Address':'Address-1',
                                 'City/ Town':'City','Contact Person':'Contact Name',
                                 'Contact No':'Phone no', 'Number Of Bed':'Beds'}, inplace=True)
hospital_data_df.columns
# Out:
# Index(['S_No', 'Region', 'Hospital_Name', 'Address-1', 'Beds', 'Validity',
#        'Phone no', 'Contact Name', 'Contact Number', 'Designation', 'Status',
#        'Remarks', 'E-Mail Id'],
#       dtype='object')

# %%
hospital_laksh_8_02_df.rename(columns={'Sr. No.':'S_No','Provider Name':'Hospital_Name', 'Address':'Address-1',
                                 'Pin Code':'Pincode','Tel No.':'Phone no'}, inplace=True)
hospital_laksh_8_02_df.columns
# Out:
# Index(['S_No', 'Hospital_Name', 'Tel Area', 'Phone no', 'Category',
#        'Address-1', 'State', 'City', 'Pincode', 'Status ', 'Remarks',
#        'Allocated'],
#       dtype='object')

# %%
hospital_laksh_23_01_df.rename(columns={'SL NO':'S_No', 'NAME OF THE HOSPITAL':'Hospital_Name', 'Number Of Bed':'Beds','ADDRESS-1':'Address-1',
                                 'ADDRESS-2':'Address-2','CITY':'City','DISTRICT':'District', 'STATE ':'State', 'PINCODE':'Pincode', 'STD CODE':'Std Code',
                                 'PHONE NO.':'Phone no'}, inplace=True)
hospital_laksh_23_01_df.columns
# Out:
# Index(['Allocated to', 'S_No', 'Hospital_Name', 'Beds', 'Contact Name',
#        'Designation', 'Contact Number', 'Email', 'Address-1', 'Address-2',
#        'City', 'District', 'State', 'Pincode', 'Std Code', 'Phone no',
#        'Status ', 'Remarks', 'Case'],
#       dtype='object')

# %%
indiahospital_laksh1_df.rename(columns={'SL. NO.':'S_No', 'NAME OF HOSPITAL':'Hospital_Name', 'ADDRESS':'Address-1',
                                 'CITY':'City', 'DISTRICT':'District', 'STATE ':'State',
                                  'TEL/FAX':'Phone no','No of Beds':'Beds'}, inplace=True)
indiahospital_laksh1_df.columns
# Out:
# Index(['S_No', 'City', 'Catogory', 'Hospital_Name', 'Address-1', 'STATE',
#        'Phone no', 'Updated Number', 'Beds', 'Zone', 'Status', 'Remarks',
#        'Unnamed: 12'],
#       dtype='object')

# %%
indiahospital_laksh2_df.rename(columns={'SL. NO.':'S_No', 'NAME OF HOSPITAL':'Hospital_Name', 'ADDRESS':'Address-1',
                                 'CITY':'City', 'DISTRICT':'District', 'STATE':'State', 'CATOGORY':'Category',
                                  'TEL/FAX':'Phone no','No OF BEDS':'Beds'}, inplace=True)
indiahospital_laksh2_df.columns
# Out:
# Index(['S_No', 'City', 'Category', 'Hospital_Name', 'Address-1', 'State',
#        'Phone no', 'Contact Name', 'Beds', 'Contact Updated', 'Status',
#        'Remarks', 'Case', 'Email'],
#       dtype='object')

# %%
indiahospital_laksh3_df.rename(columns={'SL. NO.':'S_No', 'NAME OF HOSPITAL':'Hospital_Name', 'ADDRESS':'Address-1',
                                 'CITY':'City', 'DISTRICT':'District', 'STATE':'State', 'CATEGORY':'Category',
                                  'TEL/FAX':'Phone no','No of Beds':'Beds', 'updated number':'Contact Updated'}, inplace=True)
indiahospital_laksh3_df.columns
# Out:
# Index(['S_No', 'City', 'Category', 'Hospital_Name', 'Address-1', 'State',
#        'Phone no', 'Contact Updated', 'Contact Name', 'Beds', 'Status ',
#        'Remarks', 'Case'],
#       dtype='object')

# %%
indiahospital_laksh4_df.rename(columns={'SL. NO.':'S_No', 'NAME OF HOSPITAL':'Hospital_Name', 'ADDRESS':'Address-1',
                                 'CITY':'City', 'DISTRICT':'District', 'STATE':'State', 'Catogory':'Category',
                                  'TEL/FAX':'Phone no','No OF BEDS':'Beds', 'Updated Number':'Contact Updated'}, inplace=True)
indiahospital_laksh4_df.columns
# Out:
# Index(['S_No', 'City', 'Category', 'Hospital_Name', 'Address-1', 'State',
#        'Phone no', 'Contact Updated', 'Beds', 'Status ', 'Remarks'],
#       dtype='object')

# %%
jharkhand_df.rename(columns={'S.No.':'S_No','Hospital Name':'Hospital_Name', 'Address':'Address-1',
                                 'City/ Town':'City','Contact Person':'Contact Name',
                                 'Contact Number':'Phone no'}, inplace=True)
jharkhand_df.columns
# Out:
# Index(['S_No', 'Hospital_Name', 'City', 'Address-1', 'Contact Name',
#        'Phone no'],
#       dtype='object')

# %%
mahima_hms_df.rename(columns={'S.no.':'S_No', 'Hospital':'Hospital_Name','Address':'Address-1','Address.1':'Address-2',
                               'State':'Duplicate','Unnamed: 6':'State','State Code':'Pincode', 'Number':'Beds',
                               'Beds':'Phone no'}, inplace=True)

#Removing the duplicate column
mahima_hms_df.drop('Duplicate', axis=1, inplace=True)

mahima_hms_df.columns
# Out:
# Index(['S_No', 'Hospital_Name', 'Address-1', 'Address-2', 'City', 'State',
#        'Pincode', 'Beds', 'Phone no', 'Status ', 'Remarks'],
#       dtype='object')

# %% [markdown]
# Creating master hms dataframe by merging all hms dataframes

# %%
master_hms_df = pd.concat([accurate_df,all_India_5000_df], axis=0, ignore_index=True)

print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (5282, 24)
#                                      Address-1 Address-2  Beds City  \
# 0                                     K C Road       NaN   0.0  NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN   0.0  NaN
# 2                                Kacha College       NaN   0.0  NaN
# 3                       Sangrur Road, Dhanuala       NaN   0.0  NaN
# 4                    K. C. Road, Near Obc Bank       NaN   0.0  NaN
#
#   Contact Head   Contact Name  Designation  Discipline_Systems_of_Medicine  \
# 0           NaN           NaN          NaN                             0.0
# 1           NaN           NaN          NaN                             0.0
# 2           NaN           NaN          NaN                             0.0
# 3           NaN           NaN          NaN                             0.0
# 4           NaN           NaN          NaN                             0.0
#
#   District  Hospital_Care_Type ...          Phone no Pincode Remarks S_No  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,all_India_general_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10365, 24)
#                                      Address-1 Address-2  Beds City  \
# 0                                     K C Road       NaN   0.0  NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN   0.0  NaN
# 2                                Kacha College       NaN   0.0  NaN
# 3                       Sangrur Road, Dhanuala       NaN   0.0  NaN
# 4                    K. C. Road, Near Obc Bank       NaN   0.0  NaN
#
#   Contact Head   Contact Name  Designation  Discipline_Systems_of_Medicine  \
# 0           NaN           NaN          NaN                             0.0
# 1           NaN           NaN          NaN                             0.0
# 2           NaN           NaN          NaN                             0.0
# 3           NaN           NaN          NaN                             0.0
# 4           NaN           NaN          NaN                             0.0
#
#   District  Hospital_Care_Type ...          Phone no Pincode Remarks S_No  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,fups_hms_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10371, 29)
#                                      Address-1 Address-2 Allocated to  Beds  \
# 0                                     K C Road       NaN          NaN   0.0
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN          NaN   0.0
# 2                                Kacha College       NaN          NaN   0.0
# 3                       Sangrur Road, Dhanuala       NaN          NaN   0.0
# 4                    K. C. Road, Near Obc Bank       NaN          NaN   0.0
#
#   Case City Contact Head  Contact Name Contact Number Designation  ...   \
# 0  NaN  NaN           NaN          NaN            NaN         NaN  ...
# 1  NaN  NaN           NaN          NaN            NaN         NaN  ...
# 2  NaN  NaN           NaN          NaN            NaN         NaN  ...
# 3  NaN  NaN           NaN          NaN            NaN         NaN  ...
# 4  NaN  NaN           NaN          NaN            NaN         NaN  ...
#
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hms_mahima_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10419, 30)
#                                      Address-1 Address-2 Allocated to  Beds  \
# 0                                     K C Road       NaN          NaN   0.0
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN          NaN   0.0
# 2                                Kacha College       NaN          NaN   0.0
# 3                       Sangrur Road, Dhanuala       NaN          NaN   0.0
# 4                    K. C. Road, Near Obc Bank       NaN          NaN   0.0
#
#   Case City Contact Head  Contact Name Contact Number Designation  ...   \
# 0  NaN  NaN           NaN          NaN            NaN         NaN  ...
# 1  NaN  NaN           NaN          NaN            NaN         NaN  ...
# 2  NaN  NaN           NaN          NaN            NaN         NaN  ...
# 3  NaN  NaN           NaN          NaN            NaN         NaN  ...
# 4  NaN  NaN           NaN          NaN            NaN         NaN  ...
#
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hms_alldata_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10666, 32)
#                                      Address-1 Address-2 Allocated to Beds  \
# 0                                     K C Road       NaN          NaN    0
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN          NaN    0
# 2                                Kacha College       NaN          NaN    0
# 3                       Sangrur Road, Dhanuala       NaN          NaN    0
# 4                    K. C. Road, Near Obc Bank       NaN          NaN    0
#
#   Case City Contact Head  Contact Name Contact Number Designation ...   \
# 0  NaN  NaN           NaN          NaN            NaN         NaN ...
# 1  NaN  NaN           NaN          NaN            NaN         NaN ...
# 2  NaN  NaN           NaN          NaN            NaN         NaN ...
# 3  NaN  NaN           NaN          NaN            NaN         NaN ...
# 4  NaN  NaN           NaN          NaN            NaN         NaN ...
#
#    Remarks S_No   State  State Code Status Status  Std Code Subdistrict  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hms_lakshya_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10677, 34)
#                                      Address-1 Address-2 Allocated to Beds  \
# 0                                     K C Road       NaN          NaN    0
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN          NaN    0
# 2                                Kacha College       NaN          NaN    0
# 3                       Sangrur Road, Dhanuala       NaN          NaN    0
# 4                    K. C. Road, Near Obc Bank       NaN          NaN    0
#
#   Case City Contact Head  Contact Name Contact Number Designation ...   \
# 0  NaN  NaN           NaN          NaN            NaN         NaN ...
# 1  NaN  NaN           NaN          NaN            NaN         NaN ...
# 2  NaN  NaN           NaN          NaN            NaN         NaN ...
# 3  NaN  NaN           NaN          NaN            NaN         NaN ...
# 4  NaN  NaN           NaN          NaN            NaN         NaN ...
#
#    Remarks  S_No   State State Code Status  Status  Std Code Subdistrict  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hms_dataentry_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10796, 34)
#                                      Address-1 Address-2 Allocated to Beds  \
# 0                                     K C Road       NaN          NaN    0
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN          NaN    0
# 2                                Kacha College       NaN          NaN    0
# 3                       Sangrur Road, Dhanuala       NaN          NaN    0
# 4                    K. C. Road, Near Obc Bank       NaN          NaN    0
#
#   Case City Contact Head  Contact Name Contact Number Designation ...   \
# 0  NaN  NaN           NaN          NaN            NaN         NaN ...
# 1  NaN  NaN           NaN          NaN            NaN         NaN ...
# 2  NaN  NaN           NaN          NaN            NaN         NaN ...
# 3  NaN  NaN           NaN          NaN            NaN         NaN ...
# 4  NaN  NaN           NaN          NaN            NaN         NaN ...
#
#    Remarks  S_No   State State Code Status  Status  Std Code Subdistrict  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hms_leadfile_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10821, 35)
#                                      Address-1 Address-2 Allocated to Beds  \
# 0                                     K C Road       NaN          NaN    0
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN          NaN    0
# 2                                Kacha College       NaN          NaN    0
# 3                       Sangrur Road, Dhanuala       NaN          NaN    0
# 4                    K. C. Road, Near Obc Bank       NaN          NaN    0
#
#   Case City Contact Head  Contact Name Contact Number Date ...  Remarks  S_No  \
# 0  NaN  NaN           NaN          NaN            NaN  NaN ...       nr   201
# 1  NaN  NaN           NaN          NaN            NaN  NaN ...       nb   202
# 2  NaN  NaN           NaN          NaN            NaN  NaN ...       nb   203
# 3  NaN  NaN           NaN          NaN            NaN  NaN ...      cnr   204
# 4  NaN  NaN           NaN          NaN            NaN  NaN ...      NaN   205
#
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hms_uttarakhand_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10837, 35)
#                                      Address-1 Address-2 Allocated to Beds  \
# 0                                     K C Road       NaN          NaN    0
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN          NaN    0
# 2                                Kacha College       NaN          NaN    0
# 3                       Sangrur Road, Dhanuala       NaN          NaN    0
# 4                    K. C. Road, Near Obc Bank       NaN          NaN    0
#
#   Case City Contact Head  Contact Name Contact Number Date ...  Remarks  S_No  \
# 0  NaN  NaN           NaN          NaN            NaN  NaN ...       nr   201
# 1  NaN  NaN           NaN          NaN            NaN  NaN ...       nb   202
# 2  NaN  NaN           NaN          NaN            NaN  NaN ...       nb   203
# 3  NaN  NaN           NaN          NaN            NaN  NaN ...      cnr   204
# 4  NaN  NaN           NaN          NaN            NaN  NaN ...      NaN   205
#
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hospital_data_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (10986, 37)
#                                      Address-1 Address-2 Allocated to Beds  \
# 0                                     K C Road       NaN          NaN    0
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN          NaN    0
# 2                                Kacha College       NaN          NaN    0
# 3                       Sangrur Road, Dhanuala       NaN          NaN    0
# 4                    K. C. Road, Near Obc Bank       NaN          NaN    0
#
#   Case City Contact Head  Contact Name Contact Number Date ...  S_No   State  \
# 0  NaN  NaN           NaN          NaN            NaN  NaN ...   201  Punjab
# 1  NaN  NaN           NaN          NaN            NaN  NaN ...   202  Punjab
# 2  NaN  NaN           NaN          NaN            NaN  NaN ...   203  Punjab
# 3  NaN  NaN           NaN          NaN            NaN  NaN ...   204  Punjab
# 4  NaN  NaN           NaN          NaN            NaN  NaN ...   205  Punjab
#
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hospital_laksh_8_02_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (11084, 40)
#                                      Address-1 Address-2 Allocated  \
# 0                                     K C Road       NaN       NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN       NaN
# 2                                Kacha College       NaN       NaN
# 3                       Sangrur Road, Dhanuala       NaN       NaN
# 4                    K. C. Road, Near Obc Bank       NaN       NaN
#
#   Allocated to Beds Case Category City Contact Head  Contact Name  ...   \
# 0          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
# 1          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
# 2          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
# 3          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
# 4          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
#
#     State State Code Status  Status   Std Code Subdistrict Tel Area Validity  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,hospital_laksh_23_01_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (11584, 40)
#                                      Address-1 Address-2 Allocated  \
# 0                                     K C Road       NaN       NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN       NaN
# 2                                Kacha College       NaN       NaN
# 3                       Sangrur Road, Dhanuala       NaN       NaN
# 4                    K. C. Road, Near Obc Bank       NaN       NaN
#
#   Allocated to Beds Case Category City Contact Head  Contact Name  ...   \
# 0          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
# 1          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
# 2          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
# 3          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
# 4          NaN    0  NaN      NaN  NaN           NaN          NaN  ...
#
#     State State Code Status  Status   Std Code Subdistrict Tel Area Validity  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,indiahospital_laksh1_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (12615, 45)
#                                      Address-1 Address-2 Allocated  \
# 0                                     K C Road       NaN       NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN       NaN
# 2                                Kacha College       NaN       NaN
# 3                       Sangrur Road, Dhanuala       NaN       NaN
# 4                    K. C. Road, Near Obc Bank       NaN       NaN
#
#   Allocated to Beds Case Category Catogory City Contact Head  ...  Status   \
# 0          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 1          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 2          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 3          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 4          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
#
#   Std Code Subdistrict Tel Area  Unnamed: 12  Updated Number Validity Website  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,indiahospital_laksh2_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (12981, 46)
#                                      Address-1 Address-2 Allocated  \
# 0                                     K C Road       NaN       NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN       NaN
# 2                                Kacha College       NaN       NaN
# 3                       Sangrur Road, Dhanuala       NaN       NaN
# 4                    K. C. Road, Near Obc Bank       NaN       NaN
#
#   Allocated to Beds Case Category Catogory City Contact Head  ...  Status   \
# 0          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 1          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 2          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 3          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 4          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
#
#   Std Code Subdistrict Tel Area Unnamed: 12  Updated Number  Validity Website  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,indiahospital_laksh3_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (13103, 46)
#                                      Address-1 Address-2 Allocated  \
# 0                                     K C Road       NaN       NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN       NaN
# 2                                Kacha College       NaN       NaN
# 3                       Sangrur Road, Dhanuala       NaN       NaN
# 4                    K. C. Road, Near Obc Bank       NaN       NaN
#
#   Allocated to Beds Case Category Catogory City Contact Head  ...  Status   \
# 0          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 1          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 2          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 3          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 4          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
#
#   Std Code Subdistrict Tel Area Unnamed: 12  Updated Number  Validity Website  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,indiahospital_laksh4_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (13636, 46)
#                                      Address-1 Address-2 Allocated  \
# 0                                     K C Road       NaN       NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN       NaN
# 2                                Kacha College       NaN       NaN
# 3                       Sangrur Road, Dhanuala       NaN       NaN
# 4                    K. C. Road, Near Obc Bank       NaN       NaN
#
#   Allocated to Beds Case Category Catogory City Contact Head  ...  Status   \
# 0          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 1          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 2          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 3          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 4          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
#
#   Std Code Subdistrict Tel Area Unnamed: 12  Updated Number  Validity Website  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,jharkhand_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (13673, 46)
#                                      Address-1 Address-2 Allocated  \
# 0                                     K C Road       NaN       NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN       NaN
# 2                                Kacha College       NaN       NaN
# 3                       Sangrur Road, Dhanuala       NaN       NaN
# 4                    K. C. Road, Near Obc Bank       NaN       NaN
#
#   Allocated to Beds Case Category Catogory City Contact Head  ...  Status   \
# 0          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 1          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 2          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 3          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 4          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
#
#   Std Code Subdistrict Tel Area Unnamed: 12  Updated Number  Validity Website  \
# ...

# %%
master_hms_df = pd.concat([master_hms_df,mahima_hms_df], axis=0, ignore_index=True)
print(master_hms_df.shape)
master_hms_df.head()
# Out:
# (13822, 46)
#                                      Address-1 Address-2 Allocated  \
# 0                                     K C Road       NaN       NaN
# 1  Neal Gazal Hotel, Old Sabzi Mandi, K.C Road       NaN       NaN
# 2                                Kacha College       NaN       NaN
# 3                       Sangrur Road, Dhanuala       NaN       NaN
# 4                    K. C. Road, Near Obc Bank       NaN       NaN
#
#   Allocated to Beds Case Category Catogory City Contact Head  ...  Status   \
# 0          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 1          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 2          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 3          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
# 4          NaN    0  NaN      NaN      NaN  NaN           NaN ...      NaN
#
#   Std Code Subdistrict Tel Area Unnamed: 12  Updated Number  Validity Website  \
# ...

# %%
master_hms_df.describe(include='all')
# Out:
#         Address-1  Address-2 Allocated Allocated to    Beds  \
# count       13784    10987.0        98          506  1055.0
# unique       7644     4068.0         1            1   334.0
# top     MAIN ROAD        0.0   Lakshya      Lakshya     0.0
# freq           26       64.0        98          506   177.0
# mean          NaN        NaN       NaN          NaN     NaN
# std           NaN        NaN       NaN          NaN     NaN
# min           NaN        NaN       NaN          NaN     NaN
# 25%           NaN        NaN       NaN          NaN     NaN
# 50%           NaN        NaN       NaN          NaN     NaN
# 75%           NaN        NaN       NaN          NaN     NaN
# max           NaN        NaN       NaN          NaN     NaN
#
#                                              Case  Category  \
# count                                          20       115
# unique                                         19         9
# top     Soft exp on dec 2018 so send details mail  Hospital
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='white')

# %%
sns.countplot(x="Region", data=master_hms_df)
plt.xticks(rotation=90) 
plt.show()

# %%
sns.countplot(x="State", data=master_hms_df)
plt.xticks(rotation=90) 
plt.show()

# %%
sns.countplot(x="Category", data=master_hms_df)
plt.xticks(rotation=90) 
plt.show()
